# %%
"""
Chart Visualtions for stocks using pandas library
"""

# %run assets/libraries_import.ipynb
# %run assets/functions.ipynb


google_data_frame = return_data_frame(return_data_query(stocks_list[0],from_period,to_period,interval)) #GOOGL - Google data frame
microsoft_data_frame = return_data_frame(return_data_query(stocks_list[1],from_period,to_period,interval)) #MSFT - Microsoft Data frame
ibm_data_frame = return_data_frame(return_data_query(stocks_list[2],from_period,to_period,interval)) #IBM - Microsoft Data frame

print("Statistical details of Google data frame - ")
google_data_frame.describe()
# Out:
# Statistical details of Google data frame -
#               Open         High          Low        Close    Adj Close  \
# count    43.000000    43.000000    43.000000    43.000000    43.000000
# mean   2924.001732  2953.004616  2893.859943  2924.652565  2924.652565
# std      60.536683    54.987212    62.685383    57.351276    57.351276
# min    2776.209961  2784.115967  2734.969971  2775.459961  2775.459961
# 25%    2886.645019  2931.276489  2843.085083  2880.169922  2880.169922
# 50%    2941.790039  2967.989990  2901.070068  2934.959961  2934.959961
# 75%    2967.754883  2992.310059  2942.055054  2973.579956  2973.579956
# max    3020.000000  3037.000000  2997.750000  3014.179932  3014.179932
#
#              Volume
# count  4.300000e+01
# mean   1.169342e+06
# std    3.931856e+05
# min    6.232000e+05
# 25%    9.128500e+05
# 50%    1.062500e+06
# 75%    1.333350e+06
# max    2.592500e+06

# %%
print("Statistical details of Microsoft data frame")
microsoft_data_frame.describe()
# Out:
# Statistical details of Microsoft data frame
#              Open        High         Low       Close   Adj Close  \
# count   43.000000   43.000000   43.000000   43.000000   43.000000
# mean   331.690232  334.692793  328.424651  331.887208  331.648753
# std      7.676978    7.679189    8.007596    7.578531    7.628271
# min    309.359985  309.399994  306.459991  308.130005  307.567322
# 25%    329.454987  333.075012  324.004989  328.854995  328.554260
# 50%    333.920013  336.390015  330.000000  333.200012  333.200012
# 75%    335.994995  338.755005  334.225006  336.675003  336.239853
# max    344.619995  349.670013  342.200012  343.109985  343.109985
#
#              Volume
# count  4.300000e+01
# mean   2.814288e+07
# std    8.384029e+06
# min    1.672300e+07
# 25%    2.208880e+07
# 50%    2.629790e+07
# 75%    3.102650e+07
# max    5.258870e+07

# %%
print("Statistical details of IBM data frame")
ibm_data_frame.describe()
# Out:
# Statistical details of IBM data frame
#              Open        High         Low       Close   Adj Close  \
# count   43.000000   43.000000   43.000000   43.000000   43.000000
# mean   121.022180  122.222354  120.111059  121.136105  120.727260
# std      3.432968    3.559858    3.439218    3.801842    3.839787
# min    115.000000  116.339996  114.559998  115.809998  115.809998
# 25%    118.500000  119.485001  117.654999  118.479999  118.074791
# 50%    120.745697  121.790001  119.900002  120.630974  119.910004
# 75%    122.805001  124.154999  121.654999  123.340001  122.960000
# max    130.000000  130.960007  129.520004  130.630005  130.630005
#
#              Volume
# count  4.300000e+01
# mean   5.847192e+06
# std    1.561756e+06
# min    3.220800e+06
# 25%    4.884400e+06
# 50%    5.483900e+06
# 75%    6.726852e+06
# max    1.037900e+07

# %%
# Display Line chart for certain period's Adjusted Close
show_line_chart(return_grouped_data_frame('Adj Close',stocks_list),'Adj Close','Day',"Line Chart")

# %%
# Display Line chart for certain period's Volume
show_line_chart(return_grouped_data_frame('Volume',stocks_list),'Volume','Day','Line Chart')

# %%
show_bar_chart(return_grouped_data_frame('Volume',stocks_list),'Bar Chart','Volume','Days')

# %%
show_histogram(return_grouped_data_frame('Open',stocks_list),"Histogram","Days","Open")

# %%
show_boxplot(return_grouped_data_frame('Volume',stocks_list),"Box Plot","Volume","Companies")

# %%
show_area_chart(return_grouped_data_frame('Open',stocks_list),"Area Graph","Open","Days")

# %%
show_scatter_plot(return_grouped_data_frame('Open',stocks_list),"GOOG","IBM","Scatter plot")

# %%
show_hexbin_plot(return_grouped_data_frame('Volume',stocks_list),"GOOG","IBM","Hexbin Plot")

# %%
show_desnity_plot(return_grouped_data_frame('Adj Close',stocks_list))

# %%
show_subplots(return_grouped_data_frame('Volume',stocks_list),'line')

# %%
show_subplots(return_grouped_data_frame('Volume',stocks_list),'bar')

# %%
show_subplots(return_grouped_data_frame('Volume',stocks_list),'hist')

# %%
show_subplots(return_grouped_data_frame('Volume',stocks_list),'box')

# %%
show_subplots(return_grouped_data_frame('Volume',stocks_list),'kde')

# %%
show_subplots(return_grouped_data_frame('Volume',stocks_list),'area')
